# %%
import os
import json
import pandas as pd
import psycopg2

# %% [markdown]
# #### For Aggregated -> transaction

# %%
#aggre_transaction

path1 = "C:/Users/mrinm/OneDrive/Desktop/ML Internship Projects/PhonePe Pulse/pulse/data/aggregated/transaction/country/india/state/"
agg_tran_list = os.listdir(path1)

columns1 = {"States":[], "Years":[], "Quater":[], "Transaction_type":[],"Transaction_count":[], "Transaction_amount":[]}

for state in agg_tran_list:
    curr_states = path1+state+"/"
    agg_year_list = os.listdir(curr_states)
    
    for year in agg_year_list:
        curr_year = curr_states+year+"/"
        agg_file_list = os.listdir(curr_year)

        for file in agg_file_list:
            curr_file = curr_year+file
            data = open(curr_file,"r")

            A = json.load(data)

            for i in A["data"]["transactionData"]:
                name = i["name"]
                count = i['paymentInstruments'][0]['count']
                amount = i['paymentInstruments'][0]['amount']
                columns1["Transaction_type"].append(name)
                columns1["Transaction_count"].append(count)
                columns1["Transaction_amount"].append(amount)
                columns1["States"].append(state)
                columns1["Years"].append(year)
                columns1["Quater"].append(int(file.strip(".json")))  #only selects the name of the json file i.e, 1 which is integer

aggre_transaction = pd.DataFrame(columns1)

aggre_transaction['States'] = aggre_transaction['States'].str.replace("andaman-&-nicobar-islands", "Andaman & Nicobar")
aggre_transaction['States'] = aggre_transaction['States'].str.replace("-"," ")
aggre_transaction['States'] = aggre_transaction['States'].str.title()
aggre_transaction['States'] = aggre_transaction['States'].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and Nagar Haveli and Daman and Diu ")

# %%
A
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'from': 1727740800000,
#   'to': 1735344000000,
#   'transactionData': [{'name': 'Merchant payments',
#     'paymentInstruments': [{'type': 'TOTAL',
#       'count': 655100809,
#       'amount': 389286175909.0}]},
#    {'name': 'Peer-to-peer payments',
#     'paymentInstruments': [{'type': 'TOTAL',
#       'count': 493217788,
#       'amount': 1361927136312.0}]},
#    {'name': 'Recharge & bill payments',
#     'paymentInstruments': [{'type': 'TOTAL',
#       'count': 76043195,
#       'amount': 57534056540.0}]},
#    {'name': 'Financial Services',
#     'paymentInstruments': [{'type': 'TOTAL',
#       'count': 2352084,
#       'amount': 847296537.0}]},
#    {'name': 'Others',
#     'paymentInstruments': [{'type': 'TOTAL',
#       'count': 421806,
#       'amount': 505364108.0}]}]},
#  'responseTimestamp': 1739974491270}

# %%
aggre_transaction
# Out:
#                  States Years  Quater          Transaction_type  \
# 0     Andaman & Nicobar  2018       1  Recharge & bill payments
# 1     Andaman & Nicobar  2018       1     Peer-to-peer payments
# 2     Andaman & Nicobar  2018       1         Merchant payments
# 3     Andaman & Nicobar  2018       1        Financial Services
# 4     Andaman & Nicobar  2018       1                    Others
# ...                 ...   ...     ...                       ...
# 5029        West Bengal  2024       4         Merchant payments
# 5030        West Bengal  2024       4     Peer-to-peer payments
# 5031        West Bengal  2024       4  Recharge & bill payments
# 5032        West Bengal  2024       4        Financial Services
# 5033        West Bengal  2024       4                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# 1                  1871        1.213866e+07
# 2                   298        4.525072e+05
# ...

# %%
aggre_transaction['States'].unique()
# Out:
# array(['Andaman & Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra & Nagar Haveli & Daman & Diu', 'Delhi', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal'], dtype=object)

# %% [markdown]
# #### For Aggregated -> user

# %%
#aggre_user

path2 = "C:/Users/mrinm/OneDrive/Desktop/ML Internship Projects/PhonePe Pulse/pulse/data/aggregated/user/country/india/state/"
agg_user_list = os.listdir(path2)


columns2 = {"States":[], "Years":[], "Quater":[], "Brands":[],"Transaction_count":[], "Percentage":[]}

for state in agg_user_list:
    curr_states = path2+state+"/"
    agg_year_list = os.listdir(curr_states)
    
    for year in agg_year_list:
        curr_year = curr_states+year+"/"
        agg_file_list = os.listdir(curr_year)

        for file in agg_file_list:
            curr_file = curr_year+file
            data = open(curr_file,"r")

            B = json.load(data)

            try:
                for i in B["data"]["usersByDevice"]:
                    brand = i["brand"]
                    count = i['count']
                    percentage = i['percentage']
                    columns2["Brands"].append(brand)
                    columns2["Transaction_count"].append(count)
                    columns2["Percentage"].append(percentage)
                    columns2["States"].append(state)
                    columns2["Years"].append(year)
                    columns2["Quater"].append(int(file.strip(".json"))) 

            except:
                pass

aggre_user = pd.DataFrame(columns2)

aggre_user['States'] = aggre_user['States'].str.replace("andaman-&-nicobar-islands", "Andaman & Nicobar")
aggre_user['States'] = aggre_user['States'].str.replace("-"," ")
aggre_user['States'] = aggre_user['States'].str.title()
aggre_user['States'] = aggre_user['States'].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and Nagar Haveli and Daman and Diu ")

# %%
aggre_user
# Out:
#                  States Years  Quater   Brands  Transaction_count  Percentage
# 0     Andaman & Nicobar  2018       1   Xiaomi               1665    0.247033
# 1     Andaman & Nicobar  2018       1  Samsung               1445    0.214392
# 2     Andaman & Nicobar  2018       1     Vivo                982    0.145697
# 3     Andaman & Nicobar  2018       1     Oppo                501    0.074332
# 4     Andaman & Nicobar  2018       1  OnePlus                332    0.049258
# ...                 ...   ...     ...      ...                ...         ...
# 6727        West Bengal  2022       1   Lenovo             330017    0.015056
# 6728        West Bengal  2022       1  Infinix             284678    0.012987
# 6729        West Bengal  2022       1     Asus             280347    0.012790
# 6730        West Bengal  2022       1    Apple             277752    0.012671
# 6731        West Bengal  2022       1   Others            2196334    0.100199
#
# [6732 rows x 6 columns]

# %% [markdown]
# #### For Aggregated -> insurance

# %%
#aggre_insurance

path3 = "C:/Users/mrinm/OneDrive/Desktop/ML Internship Projects/PhonePe Pulse/pulse/data/aggregated/insurance/country/india/state/"
agg_insurance_list = os.listdir(path3)

columns3 = {"States":[], "Years":[], "Quater":[], "Transaction_type":[],"Transaction_count":[], "Transaction_amount":[]}

for state in agg_user_list:
    curr_states = path3+state+"/"
    agg_year_list = os.listdir(curr_states)
    
    for year in agg_year_list:
        curr_year = curr_states+year+"/"
        agg_file_list = os.listdir(curr_year)

        for file in agg_file_list:
            curr_file = curr_year+file
            data = open(curr_file,"r")

            C = json.load(data)

            for i in C["data"]["transactionData"]:
                name = i["name"]
                count = i['paymentInstruments'][0]['count']
                amount = i['paymentInstruments'][0]['amount']
                columns3["Transaction_type"].append(name)
                columns3["Transaction_count"].append(count)
                columns3["Transaction_amount"].append(amount)
                columns3["States"].append(state)
                columns3["Years"].append(year)
                columns3["Quater"].append(int(file.strip(".json")))  #only selects the name of the json file i.e, 1 which is integer


aggre_insurance = pd.DataFrame(columns3)
aggre_insurance['States'] = aggre_insurance['States'].str.replace("andaman-&-nicobar-islands", "Andaman & Nicobar")
aggre_insurance['States'] = aggre_insurance['States'].str.replace("-"," ")
aggre_insurance['States'] = aggre_insurance['States'].str.title()
aggre_insurance['States'] = aggre_insurance['States'].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and Nagar Haveli and Daman and Diu ")

# %%
aggre_insurance
# Out:
#                 States Years  Quater Transaction_type  Transaction_count  \
# 0    Andaman & Nicobar  2020       2        Insurance                  6
# 1    Andaman & Nicobar  2020       3        Insurance                 41
# 2    Andaman & Nicobar  2020       4        Insurance                124
# 3    Andaman & Nicobar  2021       1        Insurance                225
# 4    Andaman & Nicobar  2021       2        Insurance                137
# ..                 ...   ...     ...              ...                ...
# 677        West Bengal  2023       4        Insurance              72712
# 678        West Bengal  2024       1        Insurance              79576
# 679        West Bengal  2024       2        Insurance              67048
# 680        West Bengal  2024       3        Insurance              77158
# 681        West Bengal  2024       4        Insurance              91719
#
#      Transaction_amount
# 0                1360.0
# 1               15380.0
# ...

# %% [markdown]
# #### For map -> transaction

# %%
#map_transaction

path4 = "C:/Users/mrinm/OneDrive/Desktop/ML Internship Projects/PhonePe Pulse/pulse/data/map/transaction/hover/country/india/state/"
map_tran_list = os.listdir(path4)

columns4 = {"States":[], "Years":[], "Quater":[], "Transaction_type":[],"Transaction_count":[], "Transaction_amount":[]}

for state in map_tran_list:
    curr_states = path4+state+"/"
    map_year_list = os.listdir(curr_states)
    
    for year in map_year_list:
        curr_year = curr_states+year+"/"
        map_file_list = os.listdir(curr_year)

        for file in map_file_list:
            curr_file = curr_year+file
            data = open(curr_file,"r")

            D = json.load(data)

            for i in D['data']['hoverDataList']:
                name = i["name"]
                count = i['metric'][0]['count']
                amount = i['metric'][0]['amount']
                columns4["Transaction_type"].append(name)
                columns4["Transaction_count"].append(count)
                columns4["Transaction_amount"].append(amount)
                columns4["States"].append(state)
                columns4["Years"].append(year)
                columns4["Quater"].append(int(file.strip(".json")))  #only selects the name of the json file i.e, 1 which is integer

map_transaction = pd.DataFrame(columns4)

map_transaction['States'] = map_transaction['States'].str.replace("andaman-&-nicobar-islands", "Andaman & Nicobar")
map_transaction['States'] = map_transaction['States'].str.replace("-"," ")
map_transaction['States'] = map_transaction['States'].str.title()
map_transaction['States'] = map_transaction['States'].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and Nagar Haveli and Daman and Diu ")

# %%
map_transaction
# Out:
#                   States Years  Quater                   Transaction_type  \
# 0      Andaman & Nicobar  2018       1  north and middle andaman district
# 1      Andaman & Nicobar  2018       1             south andaman district
# 2      Andaman & Nicobar  2018       1                  nicobars district
# 3      Andaman & Nicobar  2018       2  north and middle andaman district
# 4      Andaman & Nicobar  2018       2             south andaman district
# ...                  ...   ...     ...                                ...
# 20599        West Bengal  2024       4                alipurduar district
# 20600        West Bengal  2024       4         paschim bardhaman district
# 20601        West Bengal  2024       4                     nadia district
# 20602        West Bengal  2024       4                   birbhum district
# 20603        West Bengal  2024       4           purba medinipur district
#
#        Transaction_count  Transaction_amount
# ...

# %% [markdown]
# #### For map -> user

# %%
#map_user

path5 = "C:/Users/mrinm/OneDrive/Desktop/ML Internship Projects/PhonePe Pulse/pulse/data/map/user/hover/country/india/state/"
map_user_list = os.listdir(path5)

columns5 = {"States":[], "Years":[], "Quater":[], "Districts":[],"Registered_Users":[], "App_opens":[]}

for state in map_user_list:
    curr_states = path5+state+"/"
    map_year_list = os.listdir(curr_states)
    
    for year in map_year_list:
        curr_year = curr_states+year+"/"
        map_file_list = os.listdir(curr_year)

        for file in map_file_list:
            curr_file = curr_year+file
            data = open(curr_file,"r")

            E = json.load(data)

            for i in E['data']['hoverData'].items():
                district = i[0]
                registeredUsers = i[1]['registeredUsers']
                appOpens = i[1]['appOpens']
                columns5["Districts"].append(district)
                columns5["Registered_Users"].append(registeredUsers)
                columns5["App_opens"].append(appOpens)
                columns5["States"].append(state)
                columns5["Years"].append(year)
                columns5["Quater"].append(int(file.strip(".json")))  #only selects the name of the json file i.e, 1 which is integer

map_user = pd.DataFrame(columns5)

map_user['States'] = map_user['States'].str.replace("andaman-&-nicobar-islands", "Andaman & Nicobar")
map_user['States'] = map_user['States'].str.replace("-"," ")
map_user['States'] = map_user['States'].str.title()
map_user['States'] = map_user['States'].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and Nagar Haveli and Daman and Diu ")

# %%
map_user
# Out:
#                   States Years  Quater                          Districts  \
# 0      Andaman & Nicobar  2018       1  north and middle andaman district
# 1      Andaman & Nicobar  2018       1             south andaman district
# 2      Andaman & Nicobar  2018       1                  nicobars district
# 3      Andaman & Nicobar  2018       2  north and middle andaman district
# 4      Andaman & Nicobar  2018       2             south andaman district
# ...                  ...   ...     ...                                ...
# 20603        West Bengal  2024       4                alipurduar district
# 20604        West Bengal  2024       4         paschim bardhaman district
# 20605        West Bengal  2024       4                     nadia district
# 20606        West Bengal  2024       4                   birbhum district
# 20607        West Bengal  2024       4           purba medinipur district
#
#        Registered_Users  App_opens
# 0                   632          0
# ...

# %% [markdown]
# #### For map -> insurance

# %%
#map_insurance

path6 = "C:/Users/mrinm/OneDrive/Desktop/ML Internship Projects/PhonePe Pulse/pulse/data/map/insurance/hover/country/india/state/"
map_insur_list = os.listdir(path6)

columns6 = {"States":[], "Years":[], "Quater":[], "Districts":[],"Transaction_count":[], "Transaction_amount":[]}

for state in map_insur_list:
    curr_states = path6+state+"/"
    map_year_list = os.listdir(curr_states)
    
    for year in map_year_list:
        curr_year = curr_states+year+"/"
        map_file_list = os.listdir(curr_year)

        for file in map_file_list:
            curr_file = curr_year+file
            data = open(curr_file,"r")

            F = json.load(data)

            for i in F['data']['hoverDataList']:
                name = i["name"]
                count = i['metric'][0]['count']
                amount = i['metric'][0]['amount']
                columns6["Districts"].append(name)
                columns6["Transaction_count"].append(count)
                columns6["Transaction_amount"].append(amount)
                columns6["States"].append(state)
                columns6["Years"].append(year)
                columns6["Quater"].append(int(file.strip(".json")))  #only selects the name of the json file i.e, 1 which is integer


map_insurance = pd.DataFrame(columns6)

map_insurance['States'] = map_insurance['States'].str.replace("andaman-&-nicobar-islands", "Andaman & Nicobar")
map_insurance['States'] = map_insurance['States'].str.replace("-"," ")
map_insurance['States'] = map_insurance['States'].str.title()
map_insurance['States'] = map_insurance['States'].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and Nagar Haveli and Daman and Diu ")

# %%
map_insurance
# Out:
#                   States Years  Quater                          Districts  \
# 0      Andaman & Nicobar  2020       2             south andaman district
# 1      Andaman & Nicobar  2020       2                  nicobars district
# 2      Andaman & Nicobar  2020       3  north and middle andaman district
# 3      Andaman & Nicobar  2020       3             south andaman district
# 4      Andaman & Nicobar  2020       3                  nicobars district
# ...                  ...   ...     ...                                ...
# 13871        West Bengal  2024       4                alipurduar district
# 13872        West Bengal  2024       4         paschim bardhaman district
# 13873        West Bengal  2024       4                     nadia district
# 13874        West Bengal  2024       4                   birbhum district
# 13875        West Bengal  2024       4           purba medinipur district
#
#        Transaction_count  Transaction_amount
# ...

# %% [markdown]
# #### Top -> Insurance

# %%
path7 = "C:/Users/mrinm/OneDrive/Desktop/ML Internship Projects/PhonePe Pulse/pulse/data/top/insurance/country/india/state/"
top_insur_list = os.listdir(path7)

columns7 = {"States":[], "Years":[], "Quater":[], "Pincodes":[],"Transaction_count":[], "Transaction_amount":[]}


for state in top_insur_list:
    curr_states = path7+state+"/"
    top_year_list = os.listdir(curr_states)
    
    for year in top_year_list:
        curr_year = curr_states+year+"/"
        top_file_list = os.listdir(curr_year)

        for file in top_file_list:
            curr_file = curr_year+file
            data = open(curr_file,"r")

            G = json.load(data)

            for i in G['data']['pincodes']:
                entityName = i["entityName"]
                count = i['metric']['count']
                amount = i['metric']['amount']
                columns7["Pincodes"].append(entityName)
                columns7["Transaction_count"].append(count)
                columns7["Transaction_amount"].append(amount)
                columns7["States"].append(state)
                columns7["Years"].append(year)
                columns7["Quater"].append(int(file.strip(".json")))  #only selects the name of the json file i.e, 1 which is integer

top_insurance = pd.DataFrame(columns7)

top_insurance['States'] = top_insurance['States'].str.replace("andaman-&-nicobar-islands", "Andaman & Nicobar")
top_insurance['States'] = top_insurance['States'].str.replace("-"," ")
top_insurance['States'] = top_insurance['States'].str.title()
top_insurance['States'] = top_insurance['States'].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and Nagar Haveli and Daman and Diu ")

# %%
top_insurance
# Out:
#                  States Years  Quater Pincodes  Transaction_count  \
# 0     Andaman & Nicobar  2020       2   744301                  3
# 1     Andaman & Nicobar  2020       2   744104                  2
# 2     Andaman & Nicobar  2020       2   744101                  1
# 3     Andaman & Nicobar  2020       3   744112                  9
# 4     Andaman & Nicobar  2020       3   744105                  7
# ...                 ...   ...     ...      ...                ...
# 6663        West Bengal  2024       4   711101                713
# 6664        West Bengal  2024       4   700091                642
# 6665        West Bengal  2024       4   700150                627
# 6666        West Bengal  2024       4   700039                619
# 6667        West Bengal  2024       4   700156                574
#
#       Transaction_amount
# 0                  565.0
# 1                  513.0
# 2                  282.0
# 3                 3432.0
# 4                 3948.0
# ...

# %% [markdown]
# #### Top -> Transaction

# %%
#top_transaction

path8 = "C:/Users/mrinm/OneDrive/Desktop/ML Internship Projects/PhonePe Pulse/pulse/data/top/transaction/country/india/state/"
top_trans_list = os.listdir(path8)

columns8 = {"States":[], "Years":[], "Quater":[], "Pincodes":[],"Transaction_count":[], "Transaction_amount":[]}

for state in top_trans_list:
    curr_states = path8+state+"/"
    top_year_list = os.listdir(curr_states)
    
    for year in top_year_list:
        curr_year = curr_states+year+"/"
        top_file_list = os.listdir(curr_year)

        for file in top_file_list:
            curr_file = curr_year+file
            data = open(curr_file,"r")

            H = json.load(data)

            for i in H['data']['pincodes']:
                entityName = i["entityName"]
                count = i['metric']['count']
                amount = i['metric']['amount']
                columns8["Pincodes"].append(entityName)
                columns8["Transaction_count"].append(count)
                columns8["Transaction_amount"].append(amount)
                columns8["States"].append(state)
                columns8["Years"].append(year)
                columns8["Quater"].append(int(file.strip(".json")))  #only selects the name of the json file i.e, 1 which is integer
                

top_transaction = pd.DataFrame(columns8)
top_transaction['States'] = top_transaction['States'].str.replace("andaman-&-nicobar-islands", "Andaman & Nicobar")
top_transaction['States'] = top_transaction['States'].str.replace("-"," ")
top_transaction['States'] = top_transaction['States'].str.title()
top_transaction['States'] = top_transaction['States'].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and Nagar Haveli and Daman and Diu ")

# %%
top_transaction
# Out:
#                  States Years  Quater Pincodes  Transaction_count  \
# 0     Andaman & Nicobar  2018       1   744101               1622
# 1     Andaman & Nicobar  2018       1   744103               1223
# 2     Andaman & Nicobar  2018       1   744102                969
# 3     Andaman & Nicobar  2018       1   744105                685
# 4     Andaman & Nicobar  2018       1   744104                340
# ...                 ...   ...     ...      ...                ...
# 9994        West Bengal  2024       4   711101            6753348
# 9995        West Bengal  2024       4   700059            6662715
# 9996        West Bengal  2024       4   700039            6575693
# 9997        West Bengal  2024       4   734001            6432082
# 9998        West Bengal  2024       4   733134            6313560
#
#       Transaction_amount
# 0           2.769298e+06
# 1           2.238042e+06
# 2           3.519060e+06
# 3           1.298561e+06
# 4           1.039715e+06
# ...

# %% [markdown]
# #### Top -> User

# %%
#top_user

path9 = "C:/Users/mrinm/OneDrive/Desktop/ML Internship Projects/PhonePe Pulse/pulse/data/top/user/country/india/state/"
top_user_list = os.listdir(path9)

columns9 = {"States":[], "Years":[], "Quater":[], "Pincodes":[],"Registered_Users":[]}

for state in top_user_list:
    curr_states = path9+state+"/"
    top_year_list = os.listdir(curr_states)
    
    for year in top_year_list:
        curr_year = curr_states+year+"/"
        top_file_list = os.listdir(curr_year)

        for file in top_file_list:
            curr_file = curr_year+file
            data = open(curr_file,"r")

            I = json.load(data)

            for i in I['data']['pincodes']:
                entityName = i["name"]
                registeredUsers = i['registeredUsers']
                columns9["Pincodes"].append(entityName)
                columns9["Registered_Users"].append(registeredUsers)
                columns9["States"].append(state)
                columns9["Years"].append(year)
                columns9["Quater"].append(int(file.strip(".json")))  #only selects the name of the json file i.e, 1 which is integer



top_user = pd.DataFrame(columns9)
top_user['States'] = top_user['States'].str.replace("andaman-&-nicobar-islands", "Andaman & Nicobar")
top_user['States'] = top_user['States'].str.replace("-"," ")
top_user['States'] = top_user['States'].str.title()
top_user['States'] = top_user['States'].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and Nagar Haveli and Daman and Diu ")

# %%
top_user
# Out:
#                  States Years  Quater Pincodes  Registered_Users
# 0     Andaman & Nicobar  2018       1   744103              1608
# 1     Andaman & Nicobar  2018       1   744101              1108
# 2     Andaman & Nicobar  2018       1   744105              1075
# 3     Andaman & Nicobar  2018       1   744102              1006
# 4     Andaman & Nicobar  2018       1   744104               272
# ...                 ...   ...     ...      ...               ...
# 9995        West Bengal  2024       4   733134            169596
# 9996        West Bengal  2024       4   700059            169448
# 9997        West Bengal  2024       4   711302            146034
# 9998        West Bengal  2024       4   700150            142151
# 9999        West Bengal  2024       4   711106            142077
#
# [10000 rows x 5 columns]

# %% [markdown]
# ####  Connection with SQL for Aggregate -> Insurance

# %%
mydb = psycopg2.connect(host = "localhost",
                        user = "postgres",
                        port = "5432",
                        database = "phonepe_data",
                        password = "root")

cursor = mydb.cursor()

#aggregated_insurance table
create_query_1 = "CREATE TABLE if not exists aggregated_insurance(States varchar(255),Years int, Quater int, Transaction_type varchar(255), Transaction_count bigint, Transaction_amount bigint)"

cursor.execute(create_query_1)
mydb.commit()

insert_query_1 = '''INSERT INTO aggregated_insurance(States, Years, Quater, Transaction_type, Transaction_count,
                                                    Transaction_amount)
                                                    
                                                    values(%s,%s,%s,%s,%s,%s)'''
data = aggre_insurance.values.tolist()
cursor.executemany(insert_query_1,data)
mydb.commit()

# %%
aggre_insurance.values.tolist()
# Out:
# [['Andaman & Nicobar', '2020', 2, 'Insurance', 6, 1360.0],
#  ['Andaman & Nicobar', '2020', 3, 'Insurance', 41, 15380.0],
#  ['Andaman & Nicobar', '2020', 4, 'Insurance', 124, 157975.0],
#  ['Andaman & Nicobar', '2021', 1, 'Insurance', 225, 244266.0],
#  ['Andaman & Nicobar', '2021', 2, 'Insurance', 137, 181504.0],
#  ['Andaman & Nicobar', '2021', 3, 'Insurance', 230, 305235.0],
#  ['Andaman & Nicobar', '2021', 4, 'Insurance', 757, 1056380.0],
#  ['Andaman & Nicobar', '2022', 1, 'Insurance', 768, 1131287.0],
#  ['Andaman & Nicobar', '2022', 2, 'Insurance', 501, 779740.0],
#  ['Andaman & Nicobar', '2022', 3, 'Insurance', 643, 902466.0],
#  ['Andaman & Nicobar', '2022', 4, 'Insurance', 901, 1441210.0],
#  ['Andaman & Nicobar', '2023', 1, 'Insurance', 1004, 1439198.0],
#  ['Andaman & Nicobar', '2023', 2, 'Insurance', 768, 1233395.0],
#  ['Andaman & Nicobar', '2023', 3, 'Insurance', 795, 1251145.0],
#  ['Andaman & Nicobar', '2023', 4, 'Insurance', 1145, 1757821.0],
# ...

# %%
aggre_insurance.columns
# Out:
# Index(['States', 'Years', 'Quater', 'Transaction_type', 'Transaction_count',
#        'Transaction_amount'],
#       dtype='object')

# %% [markdown]
# ####  Connection with SQL for Aggregate -> Transaction

# %%
mydb = psycopg2.connect(host = "localhost",
                        user = "postgres",
                        port = "5432",
                        database = "phonepe_data",
                        password = "root")

cursor = mydb.cursor()

#aggregated_transaction table
create_query_2 = "CREATE TABLE if not exists aggregated_transaction(States varchar(255),Years int, Quater int, Transaction_type varchar(255), Transaction_count bigint, Transaction_amount bigint)"

cursor.execute(create_query_2)
mydb.commit()

insert_query_2 = '''INSERT INTO aggregated_transaction(States, Years, Quater, Transaction_type, Transaction_count,
                                                    Transaction_amount)
                                                    
                                                    values(%s,%s,%s,%s,%s,%s)'''
data = aggre_transaction.values.tolist()
cursor.executemany(insert_query_2,data)
mydb.commit()

# %%
aggre_transaction.columns
# Out:
# Index(['States', 'Years', 'Quater', 'Transaction_type', 'Transaction_count',
#        'Transaction_amount'],
#       dtype='object')

# %% [markdown]
# ####  Connection with SQL for Aggregate -> user

# %%
mydb = psycopg2.connect(host = "localhost",
                        user = "postgres",
                        port = "5432",
                        database = "phonepe_data",
                        password = "root")

cursor = mydb.cursor()

#aggregated_transaction table
create_query_3 = "CREATE TABLE if not exists aggregated_user(States varchar(255),Years int, Quater int, Brands varchar(255), Transaction_count bigint, Percentage float)"

cursor.execute(create_query_3)
mydb.commit()

insert_query_3 = '''INSERT INTO aggregated_user(States, Years, Quater, Brands, Transaction_count,
                                                    Percentage)
                                                    
                                                    values(%s,%s,%s,%s,%s,%s)'''
data = aggre_user.values.tolist()
cursor.executemany(insert_query_3,data)
mydb.commit()

# %%
aggre_user.values
# Out:
# array([['Andaman & Nicobar', '2018', 1, 'Xiaomi', 1665,
#         0.2470326409495549],
#        ['Andaman & Nicobar', '2018', 1, 'Samsung', 1445,
#         0.21439169139465875],
#        ['Andaman & Nicobar', '2018', 1, 'Vivo', 982, 0.1456973293768546],
#        ...,
#        ['West Bengal', '2022', 1, 'Asus', 280347, 0.012789677198961832],
#        ['West Bengal', '2022', 1, 'Apple', 277752, 0.012671291012088758],
#        ['West Bengal', '2022', 1, 'Others', 2196334, 0.10019869262415734]],
#       dtype=object)

# %%
aggre_user.columns
# Out:
# Index(['States', 'Years', 'Quater', 'Brands', 'Transaction_count',
#        'Percentage'],
#       dtype='object')

# %% [markdown]
# ####  Connection with SQL for map -> transaction

# %%
mydb = psycopg2.connect(host = "localhost",
                        user = "postgres",
                        port = "5432",
                        database = "phonepe_data",
                        password = "root")

cursor = mydb.cursor()

#aggregated_transaction table
create_query_4 = """
CREATE TABLE IF NOT EXISTS map_transaction (
    States VARCHAR(255),
    Years INT,
    Quater INT,
    Transaction_type VARCHAR(255),
    Transaction_count BIGINT,
    Transaction_amount DOUBLE PRECISION
)
"""

cursor.execute(create_query_4)
mydb.commit()

insert_query_4 = '''INSERT INTO map_transaction(States, Years, Quater, Transaction_type, Transaction_count,
                                                    Transaction_amount)
                                                    
                                                    values(%s,%s,%s,%s,%s,%s)'''
data = map_transaction.values.tolist()
cursor.executemany(insert_query_4,data)
mydb.commit()

# %%
map_transaction.values
# Out:
# array([['Andaman & Nicobar', '2018', 1,
#         'north and middle andaman district', 442, 931663.0770939873],
#        ['Andaman & Nicobar', '2018', 1, 'south andaman district', 5688,
#         12560249.34366581],
#        ['Andaman & Nicobar', '2018', 1, 'nicobars district', 528,
#         1139848.801225994],
#        ...,
#        ['West Bengal', '2024', 4, 'nadia district', 65274337,
#         107932013030.0],
#        ['West Bengal', '2024', 4, 'birbhum district', 36905213,
#         57787007226.0],
#        ['West Bengal', '2024', 4, 'purba medinipur district', 67833775,
#         114277126269.0]], dtype=object)

# %% [markdown]
# ####  Connection with SQL for map -> user

# %%
mydb = psycopg2.connect(host = "localhost",
                        user = "postgres",
                        port = "5432",
                        database = "phonepe_data",
                        password = "root")

cursor = mydb.cursor()

#aggregated_transaction table
create_query_5 = "CREATE TABLE if not exists map_user(States varchar(255),Years int, Quater int, Districts varchar(255), Registered_Users bigint, App_opens bigint)"

cursor.execute(create_query_5)
mydb.commit()

insert_query_5 = '''INSERT INTO map_user(States, Years, Quater, Districts, Registered_Users,
                                                    App_opens)
                                                    
                                                    values(%s,%s,%s,%s,%s,%s)'''
data = map_user.values.tolist()
cursor.executemany(insert_query_5,data)
mydb.commit()

# %%
map_user.values
# Out:
# array([['Andaman & Nicobar', '2018', 1,
#         'north and middle andaman district', 632, 0],
#        ['Andaman & Nicobar', '2018', 1, 'south andaman district', 5846,
#         0],
#        ['Andaman & Nicobar', '2018', 1, 'nicobars district', 262, 0],
#        ...,
#        ['West Bengal', '2024', 4, 'nadia district', 1861738, 98740305],
#        ['West Bengal', '2024', 4, 'birbhum district', 1114220, 73465525],
#        ['West Bengal', '2024', 4, 'purba medinipur district', 1717074,
#         108350777]], dtype=object)

# %% [markdown]
# ####  Connection with SQL for map -> Insurance

# %%
mydb = psycopg2.connect(host = "localhost",
                        user = "postgres",
                        port = "5432",
                        database = "phonepe_data",
                        password = "root")

cursor = mydb.cursor()

#aggregated_transaction table
create_query_6 = "CREATE TABLE if not exists map_insurance(States varchar(255),Years int, Quater int, Districts varchar(255), Transaction_count bigint, Transaction_amount bigint)"

cursor.execute(create_query_6)
mydb.commit()

insert_query_6 = '''INSERT INTO map_insurance(States, Years, Quater, Districts, Transaction_count,
                                                    Transaction_amount)
                                                    
                                                    values(%s,%s,%s,%s,%s,%s)'''
data = map_insurance.values.tolist()
cursor.executemany(insert_query_6,data)
mydb.commit()

# %%
map_insurance.columns
# Out:
# Index(['States', 'Years', 'Quater', 'Districts', 'Transaction_count',
#        'Transaction_amount'],
#       dtype='object')

# %% [markdown]
# ####  Connection with SQL for Top -> Insurance

# %%
mydb = psycopg2.connect(host = "localhost",
                        user = "postgres",
                        port = "5432",
                        database = "phonepe_data",
                        password = "root")

cursor = mydb.cursor()

#aggregated_transaction table
create_query_7 = "CREATE TABLE if not exists top_insurance(States varchar(255),Years int, Quater int, Pincodes varchar(255), Transaction_count bigint, Transaction_amount bigint)"

cursor.execute(create_query_7)
mydb.commit()

insert_query_7 = '''INSERT INTO top_insurance(States, Years, Quater, Pincodes, Transaction_count,
                                                    Transaction_amount)
                                                    
                                                    values(%s,%s,%s,%s,%s,%s)'''
data = top_insurance.values.tolist()
cursor.executemany(insert_query_7,data)
mydb.commit()

# %%
top_insurance.columns
# Out:
# Index(['States', 'Years', 'Quater', 'Pincodes', 'Transaction_count',
#        'Transaction_amount'],
#       dtype='object')

# %%
top_insurance.values
# Out:
# array([['Andaman & Nicobar', '2020', 2, '744301', 3, 565.0],
#        ['Andaman & Nicobar', '2020', 2, '744104', 2, 513.0],
#        ['Andaman & Nicobar', '2020', 2, '744101', 1, 282.0],
#        ...,
#        ['West Bengal', '2024', 4, '700150', 627, 761501.0],
#        ['West Bengal', '2024', 4, '700039', 619, 787836.0],
#        ['West Bengal', '2024', 4, '700156', 574, 888613.0]], dtype=object)

# %% [markdown]
# ####  Connection with SQL for Top -> User

# %%
mydb = psycopg2.connect(host = "localhost",
                        user = "postgres",
                        port = "5432",
                        database = "phonepe_data",
                        password = "root")

cursor = mydb.cursor()

#aggregated_transaction table
create_query_8 = "CREATE TABLE if not exists top_user(States varchar(255),Years int, Quater int, Pincodes varchar(255), Registered_Users bigint)"

cursor.execute(create_query_8)
mydb.commit()

insert_query_8 = '''INSERT INTO top_user(States, Years, Quater, Pincodes, Registered_Users)
                                                    
                                                    values(%s,%s,%s,%s,%s)'''
data = top_user.values.tolist()
cursor.executemany(insert_query_8,data)
mydb.commit()

# %%
top_user.columns
# Out:
# Index(['States', 'Years', 'Quater', 'Pincodes', 'Registered_Users'], dtype='object')

# %%
top_user.values
# Out:
# array([['Andaman & Nicobar', '2018', 1, '744103', 1608],
#        ['Andaman & Nicobar', '2018', 1, '744101', 1108],
#        ['Andaman & Nicobar', '2018', 1, '744105', 1075],
#        ...,
#        ['West Bengal', '2024', 4, '711302', 146034],
#        ['West Bengal', '2024', 4, '700150', 142151],
#        ['West Bengal', '2024', 4, '711106', 142077]], dtype=object)

# %% [markdown]
# ####  Connection with SQL for Top -> Transaction

# %%
mydb = psycopg2.connect(host = "localhost",
                        user = "postgres",
                        port = "5432",
                        database = "phonepe_data",
                        password = "root")

cursor = mydb.cursor()

#aggregated_transaction table
create_query_9 = "CREATE TABLE if not exists top_transaction(States varchar(255),Years int, Quater int, Pincodes varchar(255), Transaction_count bigint, Transaction_amount bigint)"

cursor.execute(create_query_9)
mydb.commit()

insert_query_9 = '''INSERT INTO top_transaction(States, Years, Quater, Pincodes, Transaction_count,
                                                    Transaction_amount)
                                                    
                                                    values(%s,%s,%s,%s,%s,%s)'''
data = top_transaction.values.tolist()
cursor.executemany(insert_query_9,data)
mydb.commit()

# %%
top_transaction.columns
# Out:
# Index(['States', 'Years', 'Quater', 'Pincodes', 'Transaction_count',
#        'Transaction_amount'],
#       dtype='object')
